# %% [markdown]
# # P1M4: Module 4 Practice
# ## Nested Conditionals
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - create nested conditional logic in code
# - print format print using escape sequence (**\**)

# %% [markdown]
# # &nbsp;
# <font size="6" color="#B24C00"  face="verdana"> <B>Tasks</B></font>

# %%
# [ ] print a string that outputs the following exactly: The new line character is "\n"
print('The new line character is \"\\n\"')
# Out:
# The new line character is "\n"

# %%
# [ ] print output that is exactly (with quotes): "That's how we escape!"
print('\"That\'s how we escape!\"')
# Out:
# "That's how we escape!"

# %%
# [ ] with only 1 print statement and using No Space Characters, output the text commented below  

# 1       one
# 22      two
# 333     three

print('1\tone\n22\ttwo\n333\tthree')
# Out:
# 1	one
# 22	two
# 333	three

# %% [markdown]
# # &nbsp;
# ## Program: quote_me() Function
# quote_me takes a string argument and returns a string that will display surrounded with **added double quotes** if printed
# - check if passed string starts with a double quote (`"\""`), then surround string with single quotations
# - if the passed string starts with single quote, or if doesn't start with a quotation mark, then surround with double quotations
#
# Test the function code passing string input as the argument to quote_me()

# %%
# [ ] create and test quote_me()
def quote_me(text):
    if text.startswith("\""):
        return "\'" + text + "\'"
    else:
        return "\"" + text + "\""
    
print(quote_me("\"CHico coming\""))
# Out:
# '"CHico coming"'

# %% [markdown]
# # &nbsp;
# ### Program: shirt order
# First get input for color and size
# - White has sizes L, M
# - Blue has sizes M, S
#
# print available or unavailable, then
# print the order confirmation of color and size
#
# *
# **hint**: set a variable "available = False" before nested if statements and
# change to True if color and size are avaliable*

# %%
# [ ] create shirt order using nested if 

color = input('enter shirt color (White/Blue): ')
size = input('enter shirt size (S/M/L): ')
available = False

if color.lower() == 'white':
    if size.upper() == 'L' or size.upper() == 'M':
        available = True
elif color.lower() == 'blue':
    if size.upper() == 'M' or size.upper() == 'S':
        available = True

if available == True:
    print('available')
    print('Order confirmed:', color, size.upper())
else:
    print('unavailable')
    print('Order unconfirmed:', color, size.upper())
# Out:
# available
# Order confirmed: WHITE L

# %% [markdown]
# # &nbsp;
# ## Program: str_analysis() Function
# Create the str_analysis() function that takes a string argument.  In the body of the function:
# - Check `if` string is digits
#   - if digits: convert to `int` and check `if` greater than 99
#     - if greater than 99, print a message about a "big number"
#     - if not greater than 99, print message about "small number"
#   - if not digits: check if string isalpha
#     - if isalpha print message about being all alpha
#     - if not isalpha print a message about being neither all alpha nor all digit
#
# call the function with a string from user input

# %%
# [ ] create and test str_analysis()
def str_analysis(text):
    if text.isdigit():
        number = int(text)
        if number > 99:
            print(number,'is a big number')
        else:
            print(number,'is a small number')
    elif text.isalpha() == True:
        print('\"'+ text + '\"', 'is being all alpha')
    else:
        print('\"' + text + '\"', 'is being neither all alpha nor all digit')

a = input('enter sthing: ')
str_analysis(a)
# Out:
# 44 is a small number

# %% [markdown]
# # &nbsp;
# ### Program: ticket_check() - finds out if a seat is available
# Call ticket_check() function with 2 arguments: *section* and *seats* requested and return True or False
# - **section** is a string and expects: general, floor
# - **seats** is an integer and expects: 1 - 10
#
# Check for valid section and seats
# - if section is *general* (or use startswith "g")
#   - if seats is 1-10 return True
# - if section is *floor* (or use starts with "f")
#   - if seats is 1-4 return True
#
# otherwise return False

# %%
# [ ] create and call ticket_check()
# your full name should be in the input prompt 
#Call ticket_check() function with 2 arguments: section and seats requested and return True or False
def ticket_check(section = None,seats = None):
    '''
    This function checks if a ticket is valid and returns True/False.
    @param:section takes general or floor
    '''
    #TODO handle the situation in which user does not supply arguments; use input()
    if section == None:
        section = input("Dominic Thomas Which section? (general or floor): ")
    
    if seats == None:
        seats = int(input("Seat number?: "))
    
    section = section.lower()
    if section == "general":
        #TODO if seats is 1-10 return True
        if seats >= 1 and seats <=10:
            print("section is general and seats <= 10")
            return True
        else:
            print("section is general but seats > 10")
            return False
    elif section == "floor":
        #TODO if seats is 1-4 return True
        if seats >= 1 and seats <= 4:
            print('section is floor and seats <= 4')
            return True
        else:
            print("section was floor but seats > 4")
            return False
    else:
        print("section was not general or floor")
        return False
    
ticket_check('floor',3)
# Out:
# section is floor and seats <= 4
# True

# %% [markdown]
# # Module 4 Practice 2
# ## `while()` loops & increments
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - create forever loops using `while` and `break`
# - use incrementing variables in a while loop
# - control while loops using Boolean operators

# %%
# [ ] use a "forever" while loop to get user input of integers to add to sum, 
# until a non-digit is entered, then break the loop and print sum
sum = 0
while True:
    user_input = input('enter an integer: ')
    if user_input.isdigit():
        sum += int(user_input)
    else:
        break

print(sum)
# Out:
# 0

# %%
# [ ] use a while True loop (forever loop) to give 4 chances for input of a correct color in a rainbow
rainbow = "red orange yellow green blue indigo violet"
chance_count = 0
while True:
    if chance_count < 4:
        user_input = input('enter a color in rainbow: ')
        if user_input.lower() in rainbow:
            print(user_input,'is correct color')
            break
        else: 
            print(user_input,'is incorrect color')
            chance_count += 1
    else:
        print('you lose')
        break
# Out:
# feff is incorrect color
# REd is correct color

# %%
# [ ] Get input for a book title, keep looping while input is Not in title format (title is every word capitalized)
title = ""
while True:
    title = input('enter a book title: ')
    if title.istitle():
        print('Title of the book "'+ title + '" is in title format')
        break
    else:
        print('Title of the book "'+ title + '" is NOT in title format')
# Out:
# Title of the book "" is NOT in title format
# Title of the book "Chico Just Sleep" is in title format

# %%
# [ ] create a math quiz question and ask for the solution until the input is correct

math_quiz = "7 x 7 = ?"
quiz_answer = '49'

print(math_quiz)
while True:
    user_input = input('Your answer: ')
    if user_input == quiz_answer:
        print('Your answer of "',user_input,'" is correct')
        break
    else:
        print('Your answer of "',user_input,'" is incorrect')
# Out:
# 7 x 7 = ?
# Your answer of " aefe " is incorrect
# Your answer of " chico " is incorrect
# Your answer of " 49 " is correct

# %% [markdown]
# ### Fix the Error

# %%
a = 5/3
print(int(a))
# Out:
# 1

# %%
# [ ] review the code, run, fix the error
tickets = int(input("enter tickets remaining (0 to quit): "))

while tickets > 0:
    # if tickets are multiple of 3 then "winner"
    if int(tickets/3) == tickets/3:        
        print("you win!")
    else:
        print("sorry, not a winner.")

    tickets = int(input("enter tickets remaining (0 to quit): "))

print("Game ended")
# Out:
# sorry, not a winner.
# sorry, not a winner.
# sorry, not a winner.
# sorry, not a winner.
# you win!
# Game ended

# %% [markdown]
# ### create a function: quiz_item()  that asks a question and tests if input is correct
# - quiz_item()has 2 parameter **strings**: question and solution
# - shows question, gets answer input
# - returns True if `answer == solution` or continues to ask question until correct answer is provided
# - use a while loop
#
# create 2 or more quiz questions that call quiz_item()
# **Hint**: provide multiple choice or T/F answers

# %%
# Create quiz_item() and 2 or more quiz questions that call quiz_item()

#quiz_item()has 2 parameter strings: question and solution

def quiz_item(question = None, solution = None):
    #TODO handle situation in which user does not supply arguments; use input()
    if question == None:
        question = input('enter a question: ')
    if solution == None:
        solution = input('enter a solution: ')
    
    while True:
        print(question,'\n')
        user_answer = input('enter your answer: ')
        if user_answer.lower() == solution.lower():
            print('your answer is correct\n')
            return True 
        else:
            print('your answer is incorrect\n')

# Quiz questions
quiz1 = "1) What is 5 + 7?\n(a) 10\n(b) 12\n(c) 13"
quiz2 = "2) True or False: The Earth is flat.\n(T or F)"

# Call quiz_item() for each question
quiz_item(quiz1, "b")
quiz_item(quiz2, "F")
# Out:
# 1) What is 5 + 7?
# (a) 10
# (b) 12
# (c) 13
#
# your answer is incorrect
#
# 1) What is 5 + 7?
# (a) 10
# (b) 12
# (c) 13
#
# your answer is correct
#
# 2) True or False: The Earth is flat.
# (T or F)
#
# your answer is incorrect
#
# 2) True or False: The Earth is flat.
# (T or F)
#
# your answer is correct
# True

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
