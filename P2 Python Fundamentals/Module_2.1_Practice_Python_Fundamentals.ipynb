# %% [markdown]
# # P2M2: Module 2 Practice - Python Fundamentals
# ## Lists
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - Create Lists
# - Access items in a list
# - Add Items to the end of a list
# - Insert items into a list
# - Delete items from a list

# %% [markdown]
# ## Create Lists

# %%
# [ ] create and populate list called days_of_week then print it

days_of_week = ["Monday","Tuesday","Wednesday"]
days_of_week.append('Thursday')
days_of_week.append('Friday')
days_of_week.append('Saturday')
days_of_week.append('Sunday')
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# [ ] after days_of_week is run above, print the days in the list at odd indexes 1,3,5
print('Orginal list:',days_of_week)
print('day at index 1:',days_of_week[1])
print('day at index 3:',days_of_week[3])
print('day at index 5:',days_of_week[5])

days_of_week.remove("Friday")
print("1",days_of_week)

#del days_of_week[3]
if "Friday" in days_of_week:
    pass
else:
    days_of_week.insert(4,"Friday")

print("2",days_of_week)
# Out:
# Orginal list: ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# day at index 1: Tuesday
# day at index 3: Thursday
# day at index 5: Saturday
# 1 ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday']
# 2 ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %% [markdown]
# ## Phone letters
# ![phone keys: number and letters](images/phone_letters.png)
# Create a list, **`phone_letters`**, where the index 0 - 9 contains the letters for keys 0 - 9.
#
# - 0 = ' ' (a space)
# - 1 = '' (empty)
# - 2 = 'ABC'
# - 3 = 'DEF'
# - etc...

# %%
# [ ] create and populate list called phone_letters then print it
phone_letters = [" ","","ABC","DEF","GHI"]
phone_letters.append('JKL')
phone_letters.append('MNO')
phone_letters.append('PQRS')
phone_letters.append('TUV')
phone_letters.append('WXYZ')

print(phone_letters)
# Out:
# [' ', '', 'ABC', 'DEF', 'GHI', 'JKL', 'MNO', 'PQRS', 'TUV', 'WXYZ']

# %% [markdown]
# ## Access Lists
# ### for the 2 cells below
# - Use days_of_week list created above
# - Run the cell above to make the list available

# %%
# [ ] create a variable: day, assign day to "Tuesday" using days_of_week[]
# [ ] print day variable

day = days_of_week[1]
print(day)
# Out:
# Tuesday

# %%
# PART 2
# [ ] assign day to days_of_week index = 5
# [ ] print day

day = days_of_week[5]
print(day)
# Out:
# Saturday

# %% [markdown]
# ## Append and Insert items into a list
#
# ### Endsday, Midsday, Resterday
# #### for the exercises below
# - Use days_of_week list created above
# - Run the cell defining days_of_week above to make the list available

# %%
# [ ] Make up a new day! - append an 8th day of the week to days_of_week 
# [ ] print days_of_week

day_8th = 'Endsday'
days_of_week.append(day_8th)
print(days_of_week)
while 'Endsday'in days_of_week:
    days_of_week.remove('Endsday')
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Endsday']
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %% [markdown]
# ### Question
# - What happens if you keep running the cell above?
# - How can you return to the initial state with the regular 7 days in days_of_week?

# %%
# [ ] Make up another new day - insert a new day into the middle of days_of_week between Wed - Thurs
# [ ] print days_of_week

another_new_day = 'Midsday'
days_of_week.insert(3,another_new_day)
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Midsday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# [ ]  Extend the weekend - insert a day between Fri & Sat in the days_of_week list
# [ ] print days_of_week

days_of_week.insert(6,'Restaday')
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Midsday', 'Thursday', 'Friday', 'Restaday', 'Saturday', 'Sunday']

# %% [markdown]
# ## Delete from a list
# ### `del` & `.pop()` some bad ideas
# #### exercises below assume days_of_week appended/inserted 3 extra days in previous exercises

# %%
# [ ] print days_of_week 
print(days_of_week)
# [ ] modified week is too long - pop() the last index of days_of_week & print .pop() value
last_value = days_of_week.pop()
print('Poped value:', last_value)
# [ ] print days_of_week
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Midsday', 'Thursday', 'Friday', 'Restaday', 'Saturday', 'Sunday']
# Poped value: Sunday
# ['Monday', 'Tuesday', 'Wednesday', 'Midsday', 'Thursday', 'Friday', 'Restaday', 'Saturday']

# %%
# [ ] print days_of_week 
print(days_of_week)
# [ ] delete (del) the new day added to the middle of the week 
del days_of_week[3]
# [ ] print days_of_week
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Midsday', 'Thursday', 'Friday', 'Restaday', 'Saturday']
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Restaday', 'Saturday']

# %%
# [ ] print days_of_week 
print(days_of_week)
# [ ] programmers choice - pop() any day in days_of week & print .pop() value
day_remove = days_of_week.pop(-2)
print('Removed day:',day_remove)
# [ ] print days_of_week
print(days_of_week)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Restaday', 'Saturday']
# Removed day: Restaday
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %% [markdown]
# ## Program:  Letter to Number Function
# ### for the exercise below
# - Use phone_letters list created above
# - Run the cell above to make the list available
#
# #### recall unit 1 using **`in`** to search for a string in a string
# ```python
# if "e" in "open":
#     print("e found")
# else:
#    print("e not found")
# ```
#
# ![phone keys: number and letters](images/phone_letters.png)
#
# ### create funtion let_to_num()
# - let_to_num() takes input of a single letter, space or empty string stored in an argument variable: letter
#   - use `while key < 10:` to try numbers 0 - 9 as index for `phone_letters` ("key" = phone dial pad key)
#   - check if `letter` variable is in the index of `phone_letters[key]`
# ```python
# key = 0
# while key < 10:
#     if # Create Code: determine if letter is **`in`** any of the phone_letters[key] where key is the index 0 -9:
#         return key
#     else:
#         key = key + 1
# return "Not Found"
# ```
# - return the number or "Not Found"
# - **call** let_to_num() to test the function so it prints the argument and return value with:
#   - space
#   - lowercase letter
#   - different letter, uppercase
#   - a number
#
# **Bonus**: create a special case to check if empty string (`""`) was submitted
# the problem is that an empty string will be found in all strings as
# ```python
# if "" in "ABC":
# ```
# is True, and is true for any phone_letters, but should `return 1`

# %%
# [ ] create let_to_num()

def let_to_num(letter):
    key = 0 
    if letter == '':
        return 1
    while key < 10:
        if letter.upper() in phone_letters[key]:
            return key
        else:
            key += 1
    return('Not Found')

print("Input: ' '  →", let_to_num(" "))      # space
print("Input: 'e'  →", let_to_num("e"))      # lowercase
print("Input: 'Q'  →", let_to_num("Q"))      # uppercase
print("Input: '7'  →", let_to_num("7"))      # number
print("Input: ''   →", let_to_num(""))       # empty string
# Out:
# Input: ' '  → 0
# Input: 'e'  → 3
# Input: 'Q'  → 7
# Input: '7'  → Not Found
# Input: ''   → 1

# %% [markdown]
# ## Challenge: reverse a string
# ### using
# - while
# - .pop()
# - insert()
#
# **`pop()`** the **first item** in the list and insert it at the beginning. Continue until the string is empty!

# %%
# [ ] Challenge: write the code for "reverse a string"
original_string = []
reverse_string = []
final_result = ''
string = 'reverse a string'
for i in string:
    original_string.append(i)
while original_string:
    poped_value = original_string.pop(0)
    reverse_string.insert(0,poped_value)
for char in reverse_string:
    final_result += char

print(final_result)
# Out:
# gnirts a esrever

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
